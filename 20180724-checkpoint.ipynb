# %% [markdown]
# # 20180712AM笔记：
#
# ## 回顾
#
# 编码方式：https://baike.baidu.com/item/%E7%BC%96%E7%A0%81%E6%96%B9%E5%BC%8F/6451499?fr=aladdin
#
# 汉字编程：https://baike.baidu.com/item/%E6%B1%89%E5%AD%97%E7%BC%96%E7%A0%81/7123465?fr=aladdin
#
# ## 今日笔记：
#
# ### 面向对象编程：
#
# 函数做单位
#
# ### 面向对象编程 Object-Oriented Programing
#
# **么是对象：**
#
# 对象是指现实中的物体或实体。
#
# **对象有什么特征：**
#
# 对象有很多属性（名词、形容词）
#
# 对象有很多行为（动作、动词）
#
# **面向对象：**
#
# 把一切都看成对象（实例）用各种对象之间的关系来描述事务。
#
# **什么是类：**
#
# 拥有相同属性和行为的对象分为一组，即为一个类；
#
# 类是用来描述对象的工具，用类可以创建此类的对象（实例）
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 类的创建语句：
#
# ![image.png](attachment:image.png)

# %%
# class.py，
class Dog:
    """这是用来描述一种小动物的类"""
    pass
dog1 = Dog()  # 调用构造函数创建一个实例对象，再用dog1变量绑定
print(id(dog1))
dog2 = Dog()  # 创建另外一个对象
print(id(dog2))

lst1 = list()  # 创建一个列表
print(id(lst1))
lst2 = list()  # 创建另外一个列表
print(id(lst2))

print(Dog)
# Out:
# 1192001200536
# 1192001134376
# 1192001136712
# 1192001137736
# <class '__main__.Dog'>

# %% [markdown]
# ## 类的官方文档
#
# https://docs.python.org/zh-cn/3/tutorial/classes.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Dog:
    '''这是一种小动物的定义，此类动物有吃的行为'''
    def eat(self, food):
        '''此方法用来描述小狗吃的行为'''
        print("小狗正在吃：", food)
        
    def sleep(self, hour):
        print("小狗睡了%d小时。"% hour)
        
    def play(self, obj):
        print("小狗正在玩：", obj)
        
dog1 = Dog() # 调用构造函数创建一个实例对象，再用dog1变量绑定
dog1.eat("money")
dog1.sleep(2)
dog1.play("basktball")

dog2 = Dog()  # 创建另外一个对象
dog2.eat("food")
# Out:
# 小狗正在吃： money
# 小狗睡了2小时。
# 小狗正在玩： basktball
# 小狗正在吃： food
