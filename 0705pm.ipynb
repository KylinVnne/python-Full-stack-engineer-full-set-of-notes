# %%
i = 1
while i <= 100:
    print("这是%d行文字" % i)
    i += 1

    
print("程序结束")
# Out:
# 这是1行文字
# 这是2行文字
# 这是3行文字
# 这是4行文字
# 这是5行文字
# 这是6行文字
# 这是7行文字
# 这是8行文字
# 这是9行文字
# 这是10行文字
# 这是11行文字
# 这是12行文字
# 这是13行文字
# 这是14行文字
# 这是15行文字
# 这是16行文字
# 这是17行文字
# 这是18行文字
# 这是19行文字
# 这是20行文字
# 这是21行文字
# 这是22行文字
# 这是23行文字
# 这是24行文字
# 这是25行文字
# 这是26行文字
# 这是27行文字
# 这是28行文字
# 这是29行文字
# 这是30行文字
# 这是31行文字
# 这是32行文字
# 这是33行文字
# 这是34行文字
# 这是35行文字
# 这是36行文字
# 这是37行文字
# 这是38行文字
# 这是39行文字
# 这是40行文字
# 这是41行文字
# 这是42行文字
# 这是43行文字
# 这是44行文字
# 这是45行文字
# 这是46行文字
# 这是47行文字
# 这是48行文字
# 这是49行文字
# 这是50行文字
# 这是51行文字
# 这是52行文字
# 这是53行文字
# 这是54行文字
# 这是55行文字
# 这是56行文字
# 这是57行文字
# 这是58行文字
# 这是59行文字
# 这是60行文字
# 这是61行文字
# 这是62行文字
# 这是63行文字
# 这是64行文字
# 这是65行文字
# 这是66行文字
# 这是67行文字
# 这是68行文字
# 这是69行文字
# 这是70行文字
# 这是71行文字
# 这是72行文字
# 这是73行文字
# 这是74行文字
# 这是75行文字
# 这是76行文字
# 这是77行文字
# 这是78行文字
# 这是79行文字
# 这是80行文字
# 这是81行文字
# 这是82行文字
# 这是83行文字
# 这是84行文字
# 这是85行文字
# 这是86行文字
# 这是87行文字
# 这是88行文字
# 这是89行文字
# 这是90行文字
# 这是91行文字
# 这是92行文字
# 这是93行文字
# 这是94行文字
# 这是95行文字
# 这是96行文字
# 这是97行文字
# 这是98行文字
# 这是99行文字
# 这是100行文字
# 程序结束

# %%
print(28.19*2)
import math
print(math.pi/2)
# Out:
# 56.38
# 1.5707963267948966
